# %% [markdown]
# # Accessing Data within Pandas - Lab

# %% [markdown]
# ## Introduction
#
# In this lab, we'll look at a dataset which contains information on World Cup matches. Let's use the pandas commands learned in the previous lesson to learn more about our data!

# %% [markdown]
# ## Objectives
#
# You will be able to:
#
# - Use pandas methods and attributes to access information about a dataset
# - Index pandas dataframes with .loc, .iloc, and column names
# - Use a boolean mask to index pandas series and dataframes

# %% [markdown]
# ## Load the Data

# %% [markdown]
# Load the file `'WorldCupMatches.csv'` as a DataFrame in pandas.

# %%
# Replace None with appropriate code

# Import pandas using the standard alias
#None
import pandas as pd

# Load 'WorldCupMatches.csv' as a DataFrame
#df = None
df=pd.read_csv('WorldCupMatches.csv')
df
# Out:
#      Year              Datetime                     Stage  \
# 0    1930  13 Jul 1930 - 15:00                    Group 1
# 1    1930  13 Jul 1930 - 15:00                    Group 4
# 2    1930  14 Jul 1930 - 12:45                    Group 2
# 3    1930  14 Jul 1930 - 14:50                    Group 3
# 4    1930  15 Jul 1930 - 16:00                    Group 1
# ..    ...                   ...                       ...
# 847  2014  05 Jul 2014 - 17:00             Quarter-finals
# 848  2014  08 Jul 2014 - 17:00                Semi-finals
# 849  2014  09 Jul 2014 - 17:00                Semi-finals
# 850  2014  12 Jul 2014 - 17:00   Play-off for third place
# 851  2014  13 Jul 2014 - 16:00                      Final
#
#                  Stadium             City Home Team Name  Home Team Goals  \
# 0                Pocitos      Montevideo          France                4
# 1         Parque Central      Montevideo             USA                3
# 2         Parque Central      Montevideo      Yugoslavia                2
# 3                Pocitos      Montevideo         Romania                3
# 4         Parque Central      Montevideo       Argentina                1
# ..                   ...              ...            ...              ...
# 847     Arena Fonte Nova        Salvador     Netherlands                0
# 848     Estadio Mineirao  Belo Horizonte          Brazil                1
# 849   Arena de Sao Paulo       Sao Paulo     Netherlands                0
# 850     Estadio Nacional        Brasilia          Brazil                0
# 851  Estadio do Maracana  Rio De Janeiro         Germany                1
#
#      Away Team Goals Away Team Name                         Win conditions  \
# 0                  1         Mexico
# 1                  0        Belgium
# 2                  1         Brazil
# 3                  1           Peru
# 4                  0         France
# ..               ...            ...                                    ...
# 847                0     Costa Rica  Netherlands win on penalties (4 - 3)
# 848                7        Germany
# 849                0      Argentina    Argentina win on penalties (2 - 4)
# 850                3    Netherlands
# 851                0      Argentina          Germany win after extra time
#
#      Attendance  Half-time Home Goals  Half-time Away Goals  \
# 0        4444.0                     3                     0
# 1       18346.0                     2                     0
# 2       24059.0                     2                     0
# 3        2549.0                     1                     0
# 4       23409.0                     0                     0
# ..          ...                   ...                   ...
# 847     51179.0                     0                     0
# 848     58141.0                     0                     5
# 849     63267.0                     0                     0
# 850     68034.0                     0                     2
# 851     74738.0                     0                     0
#
#                     Referee                  Assistant 1  \
# 0    LOMBARDI Domingo (URU)        CRISTOPHE Henry (BEL)
# 1         MACIAS Jose (ARG)     MATEUCCI Francisco (URU)
# 2       TEJADA Anibal (URU)      VALLARINO Ricardo (URU)
# 3     WARNKEN Alberto (CHI)          LANGENUS Jean (BEL)
# 4       REGO Gilberto (BRA)         SAUCEDO Ulises (BOL)
# ..                      ...                          ...
# 847   Ravshan IRMATOV (UZB)  RASULOV Abduxamidullo (UZB)
# 848   RODRIGUEZ Marco (MEX)      TORRENTERA Marvin (MEX)
# 849      C�neyt �AKIR (TUR)         DURAN Bahattin (TUR)
# 850   HAIMOUDI Djamel (ALG)         ACHIK Redouane (MAR)
# 851    Nicola RIZZOLI (ITA)        Renato FAVERANI (ITA)
#
#                     Assistant 2  RoundID    MatchID Home Team Initials  \
# 0           REGO Gilberto (BRA)      201       1096                FRA
# 1         WARNKEN Alberto (CHI)      201       1090                USA
# 2           BALWAY Thomas (FRA)      201       1093                YUG
# 3      MATEUCCI Francisco (URU)      201       1098                ROU
# 4    RADULESCU Constantin (ROU)      201       1085                ARG
# ..                          ...      ...        ...                ...
# 847    KOCHKAROV Bakhadyr (KGZ)   255953  300186488                NED
# 848       QUINTERO Marcos (MEX)   255955  300186474                BRA
# 849           ONGUN Tarik (TUR)   255955  300186490                NED
# 850     ETCHIALI Abdelhak (ALG)   255957  300186502                BRA
# 851        Andrea STEFANI (ITA)   255959  300186501                GER
#
#     Away Team Initials
# 0                  MEX
# 1                  BEL
# 2                  BRA
# 3                  PER
# 4                  FRA
# ..                 ...
# 847                CRC
# 848                GER
# 849                ARG
# 850                NED
# 851                ARG
#
# [852 rows x 20 columns]

# %% [markdown]
# ## Common Methods and Attributes

# %% [markdown]
# Use the correct method to display the **first 7 rows** of the dataset.

# %%
# Your code here
df.tail(3)
df.head(5)
# Out:
#    Year              Datetime    Stage         Stadium         City  \
# 0  1930  13 Jul 1930 - 15:00   Group 1         Pocitos  Montevideo
# 1  1930  13 Jul 1930 - 15:00   Group 4  Parque Central  Montevideo
# 2  1930  14 Jul 1930 - 12:45   Group 2  Parque Central  Montevideo
# 3  1930  14 Jul 1930 - 14:50   Group 3         Pocitos  Montevideo
# 4  1930  15 Jul 1930 - 16:00   Group 1  Parque Central  Montevideo
#
#   Home Team Name  Home Team Goals  Away Team Goals Away Team Name  \
# 0         France                4                1         Mexico
# 1            USA                3                0        Belgium
# 2     Yugoslavia                2                1         Brazil
# 3        Romania                3                1           Peru
# 4      Argentina                1                0         France
#
#   Win conditions  Attendance  Half-time Home Goals  Half-time Away Goals  \
# 0                     4444.0                     3                     0
# 1                    18346.0                     2                     0
# 2                    24059.0                     2                     0
# 3                     2549.0                     1                     0
# 4                    23409.0                     0                     0
#
#                   Referee               Assistant 1  \
# 0  LOMBARDI Domingo (URU)     CRISTOPHE Henry (BEL)
# 1       MACIAS Jose (ARG)  MATEUCCI Francisco (URU)
# 2     TEJADA Anibal (URU)   VALLARINO Ricardo (URU)
# 3   WARNKEN Alberto (CHI)       LANGENUS Jean (BEL)
# 4     REGO Gilberto (BRA)      SAUCEDO Ulises (BOL)
#
#                   Assistant 2  RoundID  MatchID Home Team Initials  \
# 0         REGO Gilberto (BRA)      201     1096                FRA
# 1       WARNKEN Alberto (CHI)      201     1090                USA
# 2         BALWAY Thomas (FRA)      201     1093                YUG
# 3    MATEUCCI Francisco (URU)      201     1098                ROU
# 4  RADULESCU Constantin (ROU)      201     1085                ARG
#
#   Away Team Initials
# 0                MEX
# 1                BEL
# 2                BRA
# 3                PER
# 4                FRA

# %% [markdown]
# Display the **last 3 rows** of the dataset.

# %%
df.tail(5)
# Out:
#      Year              Datetime                     Stage  \
# 847  2014  05 Jul 2014 - 17:00             Quarter-finals
# 848  2014  08 Jul 2014 - 17:00                Semi-finals
# 849  2014  09 Jul 2014 - 17:00                Semi-finals
# 850  2014  12 Jul 2014 - 17:00   Play-off for third place
# 851  2014  13 Jul 2014 - 16:00                      Final
#
#                  Stadium             City Home Team Name  Home Team Goals  \
# 847     Arena Fonte Nova        Salvador     Netherlands                0
# 848     Estadio Mineirao  Belo Horizonte          Brazil                1
# 849   Arena de Sao Paulo       Sao Paulo     Netherlands                0
# 850     Estadio Nacional        Brasilia          Brazil                0
# 851  Estadio do Maracana  Rio De Janeiro         Germany                1
#
#      Away Team Goals Away Team Name                         Win conditions  \
# 847                0     Costa Rica  Netherlands win on penalties (4 - 3)
# 848                7        Germany
# 849                0      Argentina    Argentina win on penalties (2 - 4)
# 850                3    Netherlands
# 851                0      Argentina          Germany win after extra time
#
#      Attendance  Half-time Home Goals  Half-time Away Goals  \
# 847     51179.0                     0                     0
# 848     58141.0                     0                     5
# 849     63267.0                     0                     0
# 850     68034.0                     0                     2
# 851     74738.0                     0                     0
#
#                    Referee                  Assistant 1  \
# 847  Ravshan IRMATOV (UZB)  RASULOV Abduxamidullo (UZB)
# 848  RODRIGUEZ Marco (MEX)      TORRENTERA Marvin (MEX)
# 849     C�neyt �AKIR (TUR)         DURAN Bahattin (TUR)
# 850  HAIMOUDI Djamel (ALG)         ACHIK Redouane (MAR)
# 851   Nicola RIZZOLI (ITA)        Renato FAVERANI (ITA)
#
#                   Assistant 2  RoundID    MatchID Home Team Initials  \
# 847  KOCHKAROV Bakhadyr (KGZ)   255953  300186488                NED
# 848     QUINTERO Marcos (MEX)   255955  300186474                BRA
# 849         ONGUN Tarik (TUR)   255955  300186490                NED
# 850   ETCHIALI Abdelhak (ALG)   255957  300186502                BRA
# 851      Andrea STEFANI (ITA)   255959  300186501                GER
#
#     Away Team Initials
# 847                CRC
# 848                GER
# 849                ARG
# 850                NED
# 851                ARG

# %%
# Your code here

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 852 entries, 0 to 851
# Data columns (total 20 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Year                  852 non-null    int64
#  1   Datetime              852 non-null    object
#  2   Stage                 852 non-null    object
#  3   Stadium               852 non-null    object
#  4   City                  852 non-null    object
#  5   Home Team Name        852 non-null    object
#  6   Home Team Goals       852 non-null    int64
#  7   Away Team Goals       852 non-null    int64
#  8   Away Team Name        852 non-null    object
#  9   Win conditions        852 non-null    object
#  10  Attendance            850 non-null    float64
#  11  Half-time Home Goals  852 non-null    int64
#  12  Half-time Away Goals  852 non-null    int64
#  13  Referee               852 non-null    object
#  14  Assistant 1           852 non-null    object
#  15  Assistant 2           852 non-null    object
#  16  RoundID               852 non-null    int64
#  17  MatchID               852 non-null    int64
#  18  Home Team Initials    852 non-null    object
#  19  Away Team Initials    852 non-null    object
# dtypes: float64(1), int64(7), object(12)
# memory usage: 133.2+ KB

# %%
df.tail(-3)
# Out:
#      Year              Datetime                     Stage  \
# 3    1930  14 Jul 1930 - 14:50                    Group 3
# 4    1930  15 Jul 1930 - 16:00                    Group 1
# 5    1930  16 Jul 1930 - 14:45                    Group 1
# 6    1930  17 Jul 1930 - 12:45                    Group 2
# 7    1930  17 Jul 1930 - 14:45                    Group 4
# ..    ...                   ...                       ...
# 847  2014  05 Jul 2014 - 17:00             Quarter-finals
# 848  2014  08 Jul 2014 - 17:00                Semi-finals
# 849  2014  09 Jul 2014 - 17:00                Semi-finals
# 850  2014  12 Jul 2014 - 17:00   Play-off for third place
# 851  2014  13 Jul 2014 - 16:00                      Final
#
#                  Stadium             City Home Team Name  Home Team Goals  \
# 3                Pocitos      Montevideo         Romania                3
# 4         Parque Central      Montevideo       Argentina                1
# 5         Parque Central      Montevideo           Chile                3
# 6         Parque Central      Montevideo      Yugoslavia                4
# 7         Parque Central      Montevideo             USA                3
# ..                   ...              ...            ...              ...
# 847     Arena Fonte Nova        Salvador     Netherlands                0
# 848     Estadio Mineirao  Belo Horizonte          Brazil                1
# 849   Arena de Sao Paulo       Sao Paulo     Netherlands                0
# 850     Estadio Nacional        Brasilia          Brazil                0
# 851  Estadio do Maracana  Rio De Janeiro         Germany                1
#
#      Away Team Goals Away Team Name                         Win conditions  \
# 3                  1           Peru
# 4                  0         France
# 5                  0         Mexico
# 6                  0        Bolivia
# 7                  0       Paraguay
# ..               ...            ...                                    ...
# 847                0     Costa Rica  Netherlands win on penalties (4 - 3)
# 848                7        Germany
# 849                0      Argentina    Argentina win on penalties (2 - 4)
# 850                3    Netherlands
# 851                0      Argentina          Germany win after extra time
#
#      Attendance  Half-time Home Goals  Half-time Away Goals  \
# 3        2549.0                     1                     0
# 4       23409.0                     0                     0
# 5        9249.0                     1                     0
# 6       18306.0                     0                     0
# 7       18306.0                     2                     0
# ..          ...                   ...                   ...
# 847     51179.0                     0                     0
# 848     58141.0                     0                     5
# 849     63267.0                     0                     0
# 850     68034.0                     0                     2
# 851     74738.0                     0                     0
#
#                       Referee                  Assistant 1  \
# 3       WARNKEN Alberto (CHI)          LANGENUS Jean (BEL)
# 4         REGO Gilberto (BRA)         SAUCEDO Ulises (BOL)
# 5       CRISTOPHE Henry (BEL)      APHESTEGUY Martin (URU)
# 6    MATEUCCI Francisco (URU)       LOMBARDI Domingo (URU)
# 7           MACIAS Jose (ARG)      APHESTEGUY Martin (URU)
# ..                        ...                          ...
# 847     Ravshan IRMATOV (UZB)  RASULOV Abduxamidullo (UZB)
# 848     RODRIGUEZ Marco (MEX)      TORRENTERA Marvin (MEX)
# 849        C�neyt �AKIR (TUR)         DURAN Bahattin (TUR)
# 850     HAIMOUDI Djamel (ALG)         ACHIK Redouane (MAR)
# 851      Nicola RIZZOLI (ITA)        Renato FAVERANI (ITA)
#
#                     Assistant 2  RoundID    MatchID Home Team Initials  \
# 3      MATEUCCI Francisco (URU)      201       1098                ROU
# 4    RADULESCU Constantin (ROU)      201       1085                ARG
# 5           LANGENUS Jean (BEL)      201       1095                CHI
# 6         WARNKEN Alberto (CHI)      201       1092                YUG
# 7           TEJADA Anibal (URU)      201       1097                USA
# ..                          ...      ...        ...                ...
# 847    KOCHKAROV Bakhadyr (KGZ)   255953  300186488                NED
# 848       QUINTERO Marcos (MEX)   255955  300186474                BRA
# 849           ONGUN Tarik (TUR)   255955  300186490                NED
# 850     ETCHIALI Abdelhak (ALG)   255957  300186502                BRA
# 851        Andrea STEFANI (ITA)   255959  300186501                GER
#
#     Away Team Initials
# 3                  PER
# 4                  FRA
# 5                  MEX
# 6                  BOL
# 7                  PAR
# ..                 ...
# 847                CRC
# 848                GER
# 849                ARG
# 850                NED
# 851                ARG
#
# [849 rows x 20 columns]

# %% [markdown]
# Get a concise summary of the data using `.info()`.

# %%
df.head(-3)
# Out:
#      Year              Datetime           Stage              Stadium  \
# 0    1930  13 Jul 1930 - 15:00          Group 1              Pocitos
# 1    1930  13 Jul 1930 - 15:00          Group 4       Parque Central
# 2    1930  14 Jul 1930 - 12:45          Group 2       Parque Central
# 3    1930  14 Jul 1930 - 14:50          Group 3              Pocitos
# 4    1930  15 Jul 1930 - 16:00          Group 1       Parque Central
# ..    ...                   ...             ...                  ...
# 844  2014  04 Jul 2014 - 13:00   Quarter-finals  Estadio do Maracana
# 845  2014  04 Jul 2014 - 17:00   Quarter-finals     Estadio Castelao
# 846  2014  05 Jul 2014 - 13:00   Quarter-finals     Estadio Nacional
# 847  2014  05 Jul 2014 - 17:00   Quarter-finals     Arena Fonte Nova
# 848  2014  08 Jul 2014 - 17:00      Semi-finals     Estadio Mineirao
#
#                 City Home Team Name  Home Team Goals  Away Team Goals  \
# 0        Montevideo          France                4                1
# 1        Montevideo             USA                3                0
# 2        Montevideo      Yugoslavia                2                1
# 3        Montevideo         Romania                3                1
# 4        Montevideo       Argentina                1                0
# ..               ...            ...              ...              ...
# 844  Rio De Janeiro          France                0                1
# 845       Fortaleza          Brazil                2                1
# 846        Brasilia       Argentina                1                0
# 847        Salvador     Netherlands                0                0
# 848  Belo Horizonte          Brazil                1                7
#
#     Away Team Name                         Win conditions  Attendance  \
# 0           Mexico                                             4444.0
# 1          Belgium                                            18346.0
# 2           Brazil                                            24059.0
# 3             Peru                                             2549.0
# 4           France                                            23409.0
# ..             ...                                    ...         ...
# 844        Germany                                            74240.0
# 845       Colombia                                            60342.0
# 846        Belgium                                            68551.0
# 847     Costa Rica  Netherlands win on penalties (4 - 3)      51179.0
# 848        Germany                                            58141.0
#
#      Half-time Home Goals  Half-time Away Goals  \
# 0                       3                     0
# 1                       2                     0
# 2                       2                     0
# 3                       1                     0
# 4                       0                     0
# ..                    ...                   ...
# 844                     0                     1
# 845                     1                     0
# 846                     1                     0
# 847                     0                     0
# 848                     0                     5
#
#                            Referee                     Assistant 1  \
# 0           LOMBARDI Domingo (URU)           CRISTOPHE Henry (BEL)
# 1                MACIAS Jose (ARG)        MATEUCCI Francisco (URU)
# 2              TEJADA Anibal (URU)         VALLARINO Ricardo (URU)
# 3            WARNKEN Alberto (CHI)             LANGENUS Jean (BEL)
# 4              REGO Gilberto (BRA)            SAUCEDO Ulises (BOL)
# ..                             ...                             ...
# 844            PITANA Nestor (ARG)            MAIDANA Hernan (ARG)
# 845  Carlos VELASCO CARBALLO (ESP)  ALONSO FERNANDEZ Roberto (ESP)
# 846           Nicola RIZZOLI (ITA)           Renato FAVERANI (ITA)
# 847          Ravshan IRMATOV (UZB)     RASULOV Abduxamidullo (UZB)
# 848          RODRIGUEZ Marco (MEX)         TORRENTERA Marvin (MEX)
#
#                     Assistant 2  RoundID    MatchID Home Team Initials  \
# 0           REGO Gilberto (BRA)      201       1096                FRA
# 1         WARNKEN Alberto (CHI)      201       1090                USA
# 2           BALWAY Thomas (FRA)      201       1093                YUG
# 3      MATEUCCI Francisco (URU)      201       1098                ROU
# 4    RADULESCU Constantin (ROU)      201       1085                ARG
# ..                          ...      ...        ...                ...
# 844    BELATTI Juan Pablo (ARG)   255953  300186485                FRA
# 845            YUSTE Juan (ESP)   255953  300186461                BRA
# 846        Andrea STEFANI (ITA)   255953  300186504                ARG
# 847    KOCHKAROV Bakhadyr (KGZ)   255953  300186488                NED
# 848       QUINTERO Marcos (MEX)   255955  300186474                BRA
#
#     Away Team Initials
# 0                  MEX
# 1                  BEL
# 2                  BRA
# 3                  PER
# 4                  FRA
# ..                 ...
# 844                GER
# 845                COL
# 846                BEL
# 847                CRC
# 848                GER
#
# [849 rows x 20 columns]

# %%
df.columns
# Out:
# Index(['Year', 'Datetime', 'Stage', 'Stadium', 'City', 'Home Team Name',
#        'Home Team Goals', 'Away Team Goals', 'Away Team Name',
#        'Win conditions', 'Attendance', 'Half-time Home Goals',
#        'Half-time Away Goals', 'Referee', 'Assistant 1', 'Assistant 2',
#        'RoundID', 'MatchID', 'Home Team Initials', 'Away Team Initials'],
#       dtype='object')

# %%
df.columns[5]
# Out:
# 'Home Team Name'

# %%
df['City'],['soccer is great']
# Out:
# (0          Montevideo
#  1          Montevideo
#  2          Montevideo
#  3          Montevideo
#  4          Montevideo
#              ...
#  847          Salvador
#  848    Belo Horizonte
#  849         Sao Paulo
#  850          Brasilia
#  851    Rio De Janeiro
#  Name: City, Length: 852, dtype: object,
#  ['soccer is great'])

# %%
# Your code here

# %%
#df=pd.read_csv('WorldCupMatches.csv')
# read the dataset into a pandas DataFrame
matchies = pd.read_csv('WorldCupMatches.csv')

# group the DataFrame by the "cities" column and get summary statistics for "Half-time Home Goals"
summary = matchies.groupby('City')['Half-time Home Goals'].describe()

# print the summary
print(summary)
# Out:
#                 count      mean       std  min  25%  50%   75%  max
# City
# Alicante          3.0  1.666667  0.577350  1.0  1.5  2.0  2.00  2.0
# Antibes           1.0  4.000000       NaN  4.0  4.0  4.0  4.00  4.0
# Arica             7.0  1.428571  1.133893  0.0  0.5  2.0  2.00  3.0
# Barcelona         8.0  0.500000  0.925820  0.0  0.0  0.0  0.50  2.0
# Bari              5.0  0.200000  0.447214  0.0  0.0  0.0  0.00  1.0
# ...               ...       ...       ...  ...  ...  ...   ...  ...
# Vina Del Mar      8.0  0.375000  0.744024  0.0  0.0  0.0  0.25  2.0
# Washington Dc     5.0  0.200000  0.447214  0.0  0.0  0.0  0.00  1.0
# Yokohama          4.0  0.000000  0.000000  0.0  0.0  0.0  0.00  0.0
# Zaragoza          3.0  0.000000  0.000000  0.0  0.0  0.0  0.00  0.0
# Zurich            5.0  2.600000  1.516575  1.0  1.0  3.0  4.00  4.0
#
# [151 rows x 8 columns]

# %%
Playing_stadium=pd.read_csv('WorldCupMatches.csv')
summary=Playing_stadium.groupby('Stadium')['Half-time Home Goals'].describe()
print(summary)
# Out:
#                   count      mean       std  min   25%  50%   75%  max
# Stadium
# Arena Amazonia      4.0  0.250000  0.500000  0.0  0.00  0.0  0.25  1.0
# Arena Fonte Nova    8.0  0.625000  1.060660  0.0  0.00  0.0  1.00  3.0
# Arena Pantanal      4.0  1.000000  0.816497  0.0  0.75  1.0  1.25  2.0
# Arena Pernambuco    6.0  0.000000  0.000000  0.0  0.00  0.0  0.00  0.0
# Arena da Baixada    4.0  0.250000  0.500000  0.0  0.00  0.0  0.25  1.0
# ...                 ...       ...       ...  ...   ...  ...   ...  ...
# Wankdorf Stadium    5.0  1.200000  0.836660  0.0  1.00  1.0  2.00  2.0
# Wembley Stadium     9.0  0.444444  0.527046  0.0  0.00  0.0  1.00  1.0
# Westfalenstadion    4.0  0.000000  0.000000  0.0  0.00  0.0  0.00  0.0
# White City          1.0  2.000000       NaN  2.0  2.00  2.0  2.00  2.0
# Zentralstadion      5.0  0.600000  0.894427  0.0  0.00  0.0  1.00  2.0
#
# [181 rows x 8 columns]

# %%
Playing_stadium=pd.read_csv('WorldCupMatches.csv')
summary=Playing_stadium.groupby('Stadium').describe()
print(summary)
# Out:
#                   Year                                                       \
#                  count    mean  std     min     25%     50%     75%     max
# Stadium
# Arena Amazonia     4.0  2014.0  0.0  2014.0  2014.0  2014.0  2014.0  2014.0
# Arena Fonte Nova   8.0  2014.0  0.0  2014.0  2014.0  2014.0  2014.0  2014.0
# Arena Pantanal     4.0  2014.0  0.0  2014.0  2014.0  2014.0  2014.0  2014.0
# Arena Pernambuco   6.0  2014.0  0.0  2014.0  2014.0  2014.0  2014.0  2014.0
# Arena da Baixada   4.0  2014.0  0.0  2014.0  2014.0  2014.0  2014.0  2014.0
# ...                ...     ...  ...     ...     ...     ...     ...     ...
# Wankdorf Stadium   5.0  1954.0  0.0  1954.0  1954.0  1954.0  1954.0  1954.0
# Wembley Stadium    9.0  1966.0  0.0  1966.0  1966.0  1966.0  1966.0  1966.0
# Westfalenstadion   4.0  1974.0  0.0  1974.0  1974.0  1974.0  1974.0  1974.0
# White City         1.0  1966.0  NaN  1966.0  1966.0  1966.0  1966.0  1966.0
# Zentralstadion     5.0  2006.0  0.0  2006.0  2006.0  2006.0  2006.0  2006.0
#
#                  Home Team Goals            ...      RoundID              \
#                            count      mean  ...          75%         max
# Stadium                                     ...
# Arena Amazonia               4.0  0.750000  ...    255931.00    255931.0
# Arena Fonte Nova             8.0  1.750000  ...    255951.50    255953.0
# Arena Pantanal               4.0  1.500000  ...    255931.00    255931.0
# Arena Pernambuco             6.0  0.833333  ...    255946.00    255951.0
# Arena da Baixada             4.0  0.500000  ...    255931.00    255931.0
# ...                          ...       ...  ...          ...         ...
# Wankdorf Stadium             5.0  3.000000  ...       212.00      3484.0
# Wembley Stadium              9.0  1.555556  ...       536.00      3479.0
# Westfalenstadion             4.0  0.750000  ...       262.25       263.0
# White City                   1.0  2.000000  ...       238.00       238.0
# Zentralstadion               5.0  1.600000  ...  97410100.00  97410200.0
#
#                  MatchID                                                      \
#                    count          mean        std          min           25%
# Stadium
# Arena Amazonia       4.0  3.001865e+08  24.500000  300186453.0  3.001865e+08
# Arena Fonte Nova     8.0  3.001865e+08  16.741202  300186464.0  3.001865e+08
# Arena Pantanal       4.0  3.001865e+08  24.494897  300186457.0  3.001865e+08
# Arena Pernambuco     6.0  3.001865e+08  23.338095  300186452.0  3.001865e+08
# Arena da Baixada     4.0  3.001865e+08  23.443194  300186463.0  3.001865e+08
# ...                  ...           ...        ...          ...           ...
# Wankdorf Stadium     5.0  1.277400e+03  25.085853       1248.0  1.263000e+03
# Wembley Stadium      9.0  1.643889e+03  37.558103       1577.0  1.633000e+03
# Westfalenstadion     4.0  2.061500e+03  92.457197       1983.0  1.988250e+03
# White City           1.0  1.653000e+03        NaN       1653.0  1.653000e+03
# Zentralstadion       5.0  9.741003e+07  17.902514   97410006.0  9.741002e+07
#
#
#                           50%           75%          max
# Stadium
# Arena Amazonia    300186482.5  3.001865e+08  300186513.0
# Arena Fonte Nova  300186492.5  3.001865e+08  300186514.0
# Arena Pantanal    300186486.0  3.001865e+08  300186511.0
# Arena Pernambuco  300186464.0  3.001865e+08  300186507.0
# Arena da Baixada  300186486.0  3.001865e+08  300186506.0
# ...                       ...           ...          ...
# Wankdorf Stadium       1278.0  1.283000e+03       1315.0
# Wembley Stadium        1635.0  1.650000e+03       1709.0
# Westfalenstadion       2043.5  2.116750e+03       2176.0
# White City             1653.0  1.653000e+03       1653.0
# Zentralstadion     97410029.0  9.741004e+07   97410050.0
#
# [181 rows x 64 columns]

# %%
Playing_stadium=pd.read_csv('WorldCupMatches.csv')
summary=Playing_stadium.groupby('Stadium').value_counts()
print(summary)
# Out:
# Stadium           Year  Datetime              Stage           City       Home Team Name             Home Team Goals  Away Team Goals  Away Team Name  Win conditions                         Attendance  Half-time Home Goals  Half-time Away Goals  Referee                 Assistant 1                  Assistant 2               RoundID   MatchID    Home Team Initials  Away Team Initials
# Arena Amazonia    2014  14 Jun 2014 - 18:00   Group D         Manaus     England                    1                2                Italy                                                  39800.0     1                     1                     Bj�rn KUIPERS (NED)     Sander VAN ROEKEL (NED)      Erwin ZEINSTRA (NED)      255931    300186513  ENG                 ITA                   1
#                         22 Jun 2014 - 18:00   Group G         Manaus     USA                        2                2                Portugal                                               40123.0     0                     1                     PITANA Nestor (ARG)     MAIDANA Hernan (ARG)         BELATTI Juan Pablo (ARG)  255931    300186483  USA                 POR                   1
#                         25 Jun 2014 - 16:00   Group E         Manaus     Honduras                   0                3                Switzerland                                            40322.0     0                     2                     PITANA Nestor (ARG)     MAIDANA Hernan (ARG)         BELATTI Juan Pablo (ARG)  255931    300186482  HON                 SUI                   1
#                         18 Jun 2014 - 18:00   Group A         Manaus     Cameroon                   0                4                Croatia                                                39982.0     0                     1                     PROENCA Pedro (POR)     MIRANDA Bertino (POR)        TRIGO Jose (POR)          255931    300186453  CMR                 CRO                   1
# Arena Fonte Nova  2014  05 Jul 2014 - 17:00   Quarter-finals  Salvador   Netherlands                0                0                Costa Rica      Netherlands win on penalties (4 - 3)   51179.0     0                     0                     Ravshan IRMATOV (UZB)   RASULOV Abduxamidullo (UZB)  KOCHKAROV Bakhadyr (KGZ)  255953    300186488  NED                 CRC                   2
#                                                                                                                                                                                                                                                                                                                                                                                                   ..
# Zentralstadion    2006  11 Jun 2006 - 15:00   Group C         Leipzig    rn">Serbia and Montenegro  0                1                Netherlands                                            43000.0     0                     1                     MERK Markus (GER)       SCHRAER Christian (GER)      SALVER Jan-Hendrik (GER)  97410100  97410006   SCG                 NED                   1
#                         14 Jun 2006 - 15:00   Group H         Leipzig    Spain                      4                0                Ukraine                                                43000.0     2                     0                     BUSACCA Massimo (SUI)   BURAGINA Francesco (SUI)     ARNET Matthias (SUI)      97410100  97410015   ESP                 UKR                   1
#                         18 Jun 2006 - 21:00   Group G         Leipzig    France                     1                1                Korea Republic                                         43000.0     1                     0                     ARCHUNDIA Benito (MEX)  RAMIREZ Jose (MEX)           VERGARA Hector (CAN)      97410100  97410029   FRA                 KOR                   1
#                         21 Jun 2006 - 16:00   Group D         Leipzig    Iran                       1                1                Angola                                                 38000.0     0                     0                     SHIELD Mark (AUS)       GIBSON Nathan (AUS)          WILSON Ben (AUS)          97410100  97410040   IRN                 ANG                   1
#                         24 Jun 2006 - 21:00   Round of 16     Leipzig    Argentina                  2                1                Mexico          Argentina win after extra time         43000.0     0                     0                     BUSACCA Massimo (SUI)   BURAGINA Francesco (SUI)     ARNET Matthias (SUI)      97410200  97410050   ARG                 MEX                   1
# Length: 835, dtype: int64

# %%
Playing_stadium=pd.read_csv('WorldCupMatches.csv')
summary=Playing_stadium.groupby('Stadium')['Half-time Home Goals'].value_counts()
print(summary)
# Out:
# Stadium           Half-time Home Goals
# Arena Amazonia    0                       3
#                   1                       1
# Arena Fonte Nova  0                       5
#                   1                       2
#                   3                       1
#                                          ..
# Westfalenstadion  0                       4
# White City        2                       1
# Zentralstadion    0                       3
#                   1                       1
#                   2                       1
# Name: Half-time Home Goals, Length: 401, dtype: int64

# %% [markdown]
# Obtain a tuple representing the **number of rows and number of columns**.

# %%
# Your code here
Playing_stadium=pd.read_csv('WorldCupMatches.csv')
summary=Playing_stadium.groupby('Stadium')['Half-time Home Goals'],['Half-time Away Goals'].value_counts()
print(summary)




#Home Team Goals', 'Away Team Goals', 'Away Team Name',
       #'Win conditions', 'Attendance', 'Half-time Home Goals',
       #'Half-time Away Goals',
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [33], line 3
#       1 # Your code here
#       2 Playing_stadium=pd.read_csv('WorldCupMatches.csv')
# ----> 3 summary=Playing_stadium.groupby('Stadium')['Half-time Home Goals'],['Half-time Away Goals'].value_counts()
#       4 print(summary)
#
# AttributeError: 'list' object has no attribute 'value_counts'

# %%
import pandas as pd

Playing_stadium = pd.read_csv('WorldCupMatches.csv')
summary = Playing_stadium.groupby(['Stadium', 'Half-time Home Goals', 'Half-time Away Goals'])['Stadium'].count()
print(summary)
# Out:
# Stadium           Half-time Home Goals  Half-time Away Goals
# Arena Amazonia    0                     1                       2
#                                         2                       1
#                   1                     1                       1
# Arena Fonte Nova  0                     0                       4
#                                         3                       1
#                                                                ..
# White City        2                     1                       1
# Zentralstadion    0                     0                       2
#                                         1                       1
#                   1                     0                       1
#                   2                     0                       1
# Name: Stadium, Length: 560, dtype: int64

# %% [markdown]
# Use the appropriate attribute to get the **column names**.

# %%
# Your code here

# %% [markdown]
# ## Selecting DataFrame Information

# %% [markdown]
# When looking at the DataFrame's `.head()` and `.tail()`, you might have noticed that the games are structured chronologically in the DataFrame.
#
# Use the right selection method to display all the information from the 3rd to the 5th game (i.e. **select rows 3 through 5 inclusive**).

# %%
# Your code here

# %% [markdown]
# Now, display the info from **game 5-9** (inclusive), but **only the `"Home Team Name"` and the `"Away Team Name"` columns**.

# %%
# Your code here

# %% [markdown]
# Next, we'd like the information on all the games played in **Group 3** for the **1950** World Cup.

# %% [markdown]
# Hint: You can combine conditions like this:
#
# `df[(condition1) | (condition2)]`  -> Returns rows where either condition is true
#
# `df[(condition1) & (condition2)]`  -> Returns rows where both conditions are true

# %%
# Your code here

# %% [markdown]
# Let's repeat the command above, but this time display **only the attendance column** for the Group 3 games.

# %%
# Your code here

# %% [markdown]
# Throughout the entire history of the World Cup as recorded in this dataset, **how many home games were played by the Netherlands**?
#
# (Remember that you can use the `len()` built-in function to find the number of rows in a DataFrame.)

# %%
# Your code here

# %% [markdown]
# **How many games were played by the Netherlands in total**?

# %%
# Your code here

# %% [markdown]
# Next, let's try and figure out **how many games the USA played in the 2014 World Cup**.

# %%
# Your code here

# %% [markdown]
# Now, let's try to find out **how many countries participated in the 1986 World Cup**.

# %% [markdown]
# Hint 1: As a first step, create a new dataset that only contains games in that year.
#
# Hint 2: Make sure you don't end up with duplicate country names. Consider using `set()` or `.unique()`.

# %%
# Your code here

# %% [markdown]
# ## Changing Values and Creating New Columns

# %% [markdown]
# In World Cup history, **how many matches had 5 goals or more in total**? Create a column `"Total Goals"` to answer this question.

# %%
# Your code here

# %% [markdown]
# Now **create a new column `"Half-time Goals"`** in `df` that includes both home and away values.

# %%
# Your code here

# %%
# Run this cell without changes to see your new column
df.columns

# %% [markdown]
# Run the code below. You'll notice that for Korea, there are records for both North-Korea (Korea DPR) and South-Korea (Korea Republic).

# %%
# Run this cell without changes

# Diaplay all records containing the string 'Korea'
df.loc[df['Home Team Name'].str.contains('Korea'), 'Home Team Name']

# %% [markdown]
# Imagine that, for some reason, we simply want Korea listed as one entry, so we want to replace every "Home Team Name" and "Away Team Name" entry that contains "Korea" to simply "Korea". In the same way, we want to change the columns "Home Team Initials" and "Away Team Initials" to NSK (North & South Korea) instead of "KOR" and "PRK".

# %%
# Update the 'Home Team Name' and 'Home Team Initials' columns

# %% [markdown]
# Make sure to verify your answer!

# %%
# Check the updated columns

# %% [markdown]
# ## Summary
#
# In this lab, you practiced accessing data within Pandas!
