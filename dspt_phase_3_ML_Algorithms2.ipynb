# %% [markdown]
# <a href="https://colab.research.google.com/github/sgathai/dsc-data-serialization-lab/blob/master/dspt_phase_3_ML_Algorithms2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## K Nearest Neighbors

# %% [markdown]
# ### How kNN works?
#
# ![knn](https://miro.medium.com/max/700/1*YWKvGH4kKOtCvlX950LM9g.jpeg)
#
# Note:
#
# 1. What does the k in kNN mean? How do you choose the best k?
#
# https://towardsdatascience.com/how-to-find-the-optimal-value-of-k-in-knn-35d936e554eb
#
#
# 2. How is classification different from regression with kNN?

# %% [markdown]
# ### Distance metrics
#
# ![knn](https://miro.medium.com/max/700/1*Lh6R4QArolCRdzF7jjSzDw.jpeg)
#
# https://scikit-learn.org/stable/modules/generated/sklearn.neighbors.DistanceMetric.html#sklearn.neighbors.DistanceMetric
#
# https://towardsdatascience.com/distance-functions-in-machine-learning-a-primer-in-simple-language-with-few-action-points-f5e328759b24

# %% [markdown]
# ### When to use kNN
#
#
#
# *   For applications that require high accuracy but that do not require a human-readable model
# *   Predictions are not requested frequently
# *   Small, noise free datasets

# %% [markdown]
# # Naive Bayes Classifier

# %% [markdown]
# ## How Naive Bayes works
#
# ![nb](https://www.analyticsvidhya.com/wp-content/uploads/2015/09/Bayes_rule-300x172-300x172.png)
#
# Example:
#
# ![data](https://miro.medium.com/max/700/1*i3PW6FunfE9BMXuO8EtOwQ.png)
#
# Create frequency tables:
#
# Variable 1:
#
# ![v1](https://miro.medium.com/max/700/1*mYXgkXY8f1FSKOG6NSHC0w.png)
#
# Variable 2:
#
# ![v2](https://miro.medium.com/max/700/1*f09RsCQWhgivap4Smz8QHQ.png)
#
# Variable 3:
#
# ![v3](https://miro.medium.com/max/700/1*1xTN6yH_hn0zJNgBsNi5NA.png)
#
# Likelihood:
#
# ![lh](https://miro.medium.com/max/484/1*cJmZWhNakedlGUr0NhkgdA.png)

# %% [markdown]
# ## Key things to note:
#
#
# Naive Bayes is parametric:
#
# *   Do thorough preprocessing
# *   Be keen when doing feature selection

# %% [markdown]
# ## SVM
#
# 1.   How does it work?
#
# ![svm.PNG](data:image/png;base64,...)
#
# ![svm1.PNG](data:image/png;base64,...)
#
#
# 2.   What loss function are we optimising?
#
# > Margin: $ \frac{2}{\parallel \theta \parallel} $
